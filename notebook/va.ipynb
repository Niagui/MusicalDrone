# %%
import essentia
import numpy as np
import matplotlib.pyplot as plt
import utils
from essentia.standard import MonoLoader, TensorflowPredictMusiCNN, TensorflowPredict2D
# Out:
# [   INFO   ] MusicExtractorSVM: no classifier models were configured by default
# 2025-09-20 04:56:29.783343: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-20 04:56:29.790231: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2025-09-20 04:56:29.909805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:29.909882: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:29.910100: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.910783: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.910891: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.911335: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.911884: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.912759: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.913487: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.913833: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2025-09-20 04:56:29.913849: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.165842: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.165877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.165885: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.176237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.176294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.176308: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.176326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.176332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.176338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.177217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.177242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.177281: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.177294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.177300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.177306: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.671424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.671482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.671496: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.671512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.671519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.671525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.691183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.691245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.691260: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.691280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.691286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.691293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.695591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.695658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.695681: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.695696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.695702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.695708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.700865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.700958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.700975: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.700990: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.700997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.701003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.701251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.701267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.701277: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.701288: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.701295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.701302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.702901: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.702954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.702968: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.702983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.702991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.702998: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.705366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.705422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.705437: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.705451: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.705457: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.705462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.706822: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.706867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.706880: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.706894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.706900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.706905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.708771: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.708863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.708878: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.708892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.708898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.708904: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.711770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.711831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.711851: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.711870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.711877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.711884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.716627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.716703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.716724: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.716747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.716755: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.716763: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.720827: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.720900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.720919: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.720931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.720937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.720943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.723773: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.723821: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.723836: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.723851: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.723860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.723868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.739692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.739758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.739775: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.739794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.739800: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.739806: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.762331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.762405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.762431: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.762452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.762461: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.762468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.775302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.775365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.775381: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.775397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.775404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.775410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.779148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.779237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.779258: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.779276: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.779284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.779290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.782919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.782989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.783007: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.783022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.783029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.783035: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.787446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.787488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.787500: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.787512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.787518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.787523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:30.789643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:30.789703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:30.789719: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:30.789739: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:30.789745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:30.789797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N

# %%
AUDIO = 'audio/testSong.mp3'

audio = MonoLoader(filename=AUDIO, sampleRate=16000, resampleQuality=4)()
embedding_model = TensorflowPredictMusiCNN(graphFilename="models/msd-musicnn-1.pb", output="model/dense/BiasAdd")
embeddings = embedding_model(audio)

model = TensorflowPredict2D(graphFilename="models/deam-msd-musicnn-2.pb", output="model/Identity")

# predictions.shape
# windowLength = 3 sec, hopLength = 1.5 seconds
predictions = model(embeddings)
# Out:
# 2025-09-20 04:56:31.327126: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:31.327217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:31.327242: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:31.327261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:31.327268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:31.327276: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:31.332055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:31.332141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:31.332161: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:31.332181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:31.332189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:31.332195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:31.336025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:31.336067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:31.336080: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:31.336094: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:31.336101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:31.336106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `models/msd-musicnn-1.pb`
# 2025-09-20 04:56:31.352888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:31.352925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:31.352937: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:31.352948: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:31.352954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:31.352960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:31.473368: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3792925000 Hz
# 2025-09-20 04:56:33.792381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:33.792468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:33.792492: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:33.792504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:33.792532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:33.792547: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:33.793758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:33.793783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:33.793793: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:33.793802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:33.793808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:33.793813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:33.797170: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:33.797208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:33.797222: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:33.797233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:33.797238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:33.797244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:33.797972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:33.797992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:33.798001: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:33.798007: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:33.798013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:33.798018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `models/deam-msd-musicnn-2.pb`
# 2025-09-20 04:56:33.799911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:33.799939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:33.799951: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:33.799961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:33.799967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:33.799972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2025-09-20 04:56:33.809085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-20 04:56:33.809129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4060 Laptop GPU computeCapability: 8.9
# coreClock: 2.01GHz coreCount: 24 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 238.45GiB/s
# 2025-09-20 04:56:33.809143: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-09-20 04:56:33.809154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-09-20 04:56:33.809160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2025-09-20 04:56:33.809165: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N

# %%
def normalize(values):
    # arousal and valences are ranged from [1,9]
    # normalize to [-1,1]
    v = np.asarray(values, dtype=float)
    return 2 * ((v - 1) / 8) - 1

# %%
predictionsN = normalize(predictions)
utils.save_as_json('va', predictionsN.tolist())

# %%
timeStamps = np.linspace(0, utils.get_duration(audio_file=AUDIO), num=len(predictionsN), endpoint=False)
utils.save_as_json('timeStamps', timeStamps.tolist())

# %%
len(audio)
# Out:
# 3178561

# %%
def plotVA(predictions, duration=45.0):
    valence = predictions[:, 0]
    arousal = predictions[:, 1]

    n = len(predictions)
    hop = duration / n
    time = np.arange(n) * hop + hop / 2.0

    plt.figure(figsize=(9,4))
    plt.plot(time, valence, label="Valence")
    plt.plot(time, arousal, label="Arousal")
    plt.xlabel('Time(s)')
    plt.ylabel('score')
    plt.title('V/A over time')
    plt.legend()
    plt.tight_layout()
    plt.show()
    return

# %%
plotVA(predictions=predictions)

# %%
from matplotlib.animation import FuncAnimation, PillowWriter

def animateVA(predictions):
    valence = predictions[:, 0]
    arousal = predictions[:, 1]
    n = len(predictions)

    fig, ax = plt.subplots(figsize=(5,5))
    ax.set_xlabel("Valence", loc='right', labelpad=15)
    ax.set_ylabel("Arousal", loc='top', labelpad=15)
    ax.set_title("VA on 2D plane")

    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')

    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_xlim(-1, 1)
    ax.set_ylim(-1, 1)

    dot, = ax.plot([],[], marker='o', markersize=8, linestyle="")

    def init():
        dot.set_data([],[])
        return dot,

    def update(frame):
        # X means the animation is ending
        if frame >= n-5:
            dot.set_marker('X')
        dot.set_data([valence[frame]], [arousal[frame]])
        return dot,
    
    animation = FuncAnimation(fig, update, frames=n, init_func=init, blit=True)
    animation.save('VA_on_2d_plane.gif', writer=PillowWriter(fps=8))
    plt.show()
    plt.close()

# %%
animateVA(predictions=predictions)

# %%
def polarCoordinate(predictions):
    valence = predictions[:, 0]
    arousal = predictions[:, 1]

    res = []
    r = np.sqrt(valence**2 + arousal**2)
    theta = np.arctan2(valence, arousal) * 180 / np.pi
    theta = np.where(theta < 0, theta + 360, theta)

    return zip(r, theta)

# %%
coordinates = np.array(list(polarCoordinate(predictions=predictions)))

# %%
def hard_classify(theta):
    if 0 <= theta < 22.5:
        return "happy"
    elif 22.5 <= theta < 45:
        return "elated"
    elif 45 <= theta < 67.5:
        return "excited"
    elif 67.5 <= theta < 90:
        return "alert"
    elif 90 <= theta < 112.5:
        return "tense"
    elif 112.5 <= theta < 135:
        return "nervous"
    elif 135 <= theta < 157.5:
        return "stressed"
    elif 157.5 <= theta < 180:
        return "upset"
    elif 180 <= theta < 202.5:
        return "sad"
    elif 202.5 <= theta < 225:
        return "depressed"
    elif 225 <= theta < 247.5:
        return "lethargic"
    elif 247.5 <= theta < 270:
        return "fatigued"
    elif 270 <= theta < 292.5:
        return "calm"
    elif 292.5 <= theta < 315:
        return "relaxed"
    elif 315 <= theta < 337.5:
        return "serene"
    else:
        return "contented"

hardClassifyMatrix = np.vectorize(hard_classify)

# %%
emotionCennters = {
    "happy": [0.9, 0.1],
    "surprise": [0.3, 0.9],
    "sad": [-0.8, -0.5],
    "angry": [-0.1, 0.8],
    # "fear": [-0.3, 0.8],
    # "disgust": [-0.4, 0.6],
}

def soft_classify(point, sigma=0.3):
    #Uses Radial Basis Function Kernel

    weights = {}

    for emotion, center in emotionCennters.items():
        dist = np.linalg.norm(point - center)
        weights[emotion] = np.exp(-dist**2 / (2 * sigma**2))

    #normalize
    total = sum(weights.values())
    for k in weights:
        weights[k] /= total
        
    return weights

# %%
hlabels = hardClassifyMatrix(coordinates[:, 1])
hlabels
# Out:
# array(['elated', 'elated', 'elated', 'elated', 'elated', 'elated',
#        'excited', 'elated', 'elated', 'excited', 'excited', 'elated',
#        'elated', 'elated', 'elated', 'elated', 'elated', 'elated',
#        'excited', 'excited', 'excited', 'excited', 'excited', 'excited',
#        'elated', 'excited', 'elated', 'elated', 'excited', 'excited',
#        'elated', 'elated', 'excited', 'excited', 'excited', 'excited',
#        'excited', 'elated', 'excited', 'elated', 'elated', 'elated',
#        'elated', 'elated', 'elated', 'excited', 'excited', 'elated',
#        'elated', 'elated', 'elated', 'elated', 'elated', 'elated',
#        'elated', 'excited', 'excited', 'excited', 'excited', 'excited',
#        'excited', 'excited', 'elated', 'elated', 'elated', 'elated',
#        'elated', 'elated', 'elated', 'elated', 'elated', 'elated',
#        'elated', 'elated', 'elated', 'elated', 'elated', 'elated',
#        'elated', 'elated', 'elated', 'elated', 'elated', 'excited',
#        'excited', 'excited', 'excited', 'excited', 'excited', 'excited',
#        'excited', 'elated', 'excited', 'excited', 'excited', 'excited',
#        'excited', 'elated', 'excited', 'excited', 'excited', 'elated',
#        'elated', 'excited', 'excited', 'excited', 'excited', 'elated',
#        'elated', 'elated', 'elated', 'elated', 'excited', 'elated',
#        'elated', 'elated', 'excited', 'excited', 'elated', 'elated',
#        'elated', 'excited', 'elated', 'elated', 'elated', 'elated',
#        'elated', 'elated', 'elated', 'elated', 'elated', 'elated'],
#       dtype='<U7')

# %%
slabels = [soft_classify(point) for point in predictions]
slabels
utils.saveAsJson('soft_label', slabels)

# %%
res = []
for label in slabels:
    max_key = max(label, key=label.get)
    print(max_key)
# Out:
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise
# surprise

# %%
duration = utils.getDurtion(AUDIO)
duration
# Out:
# 198.66

# %%
def plotEmotion(emotions, duration):
    
    return
