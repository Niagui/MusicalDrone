# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt


audiofile = 'audio/testSong.mp3'

ya, sra = librosa.load(audiofile)

y = librosa.resample(ya, orig_sr=sra, target_sr=16000)
hop_length = 512
tempo, beattrack = librosa.beat.beat_track(y=y, sr=16000, hop_length=hop_length, units='time')
# beat_times = librosa.frames_to_time(beattrack, sr=16000, hop_length=hop_length)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/niagui/miniconda3/envs/essentia/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/niagui/miniconda3/envs/essentia/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/niagui/miniconda3/envs/essentia/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...
